# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
df = pd.read_csv('https://github.com/Nine587403/DataScience2/blob/main/Wine.csv?raw=true')

# %%
df.columns = ['class','alcohol','malicAcid','ash','ashalcalinity','magnesium','totalPhenols','flavanoids',\
                'nonFlavanoidPhenols','proanthocyanins','colorIntensity','hue','od280_od315','proline']

# %%
df.head(10)
# Out:
#    class  alcohol  malicAcid   ash  ...  colorIntensity   hue  od280_od315  proline
# 0      1    13.20       1.78  2.14  ...            4.38  1.05         3.40     1050
# 1      1    13.16       2.36  2.67  ...            5.68  1.03         3.17     1185
# 2      1    14.37       1.95  2.50  ...            7.80  0.86         3.45     1480
# 3      1    13.24       2.59  2.87  ...            4.32  1.04         2.93      735
# 4      1    14.20       1.76  2.45  ...            6.75  1.05         2.85     1450
# 5      1    14.39       1.87  2.45  ...            5.25  1.02         3.58     1290
# 6      1    14.06       2.15  2.61  ...            5.05  1.06         3.58     1295
# 7      1    14.83       1.64  2.17  ...            5.20  1.08         2.85     1045
# 8      1    13.86       1.35  2.27  ...            7.22  1.01         3.55     1045
# 9      1    14.10       2.16  2.30  ...            5.75  1.25         3.17     1510
#
# [10 rows x 14 columns]

# %%
df.tail(10)
# Out:
#      class  alcohol  malicAcid  ...   hue  od280_od315  proline
# 167      3    13.58       2.58  ...  0.74         1.80      750
# 168      3    13.40       4.60  ...  0.67         1.92      630
# 169      3    12.20       3.03  ...  0.66         1.83      510
# 170      3    12.77       2.39  ...  0.57         1.63      470
# 171      3    14.16       2.51  ...  0.62         1.71      660
# 172      3    13.71       5.65  ...  0.64         1.74      740
# 173      3    13.40       3.91  ...  0.70         1.56      750
# 174      3    13.27       4.28  ...  0.59         1.56      835
# 175      3    13.17       2.59  ...  0.60         1.62      840
# 176      3    14.13       4.10  ...  0.61         1.60      560
#
# [10 rows x 14 columns]

# %%
df.sample(10)
# Out:
#      class  alcohol  malicAcid  ...   hue  od280_od315  proline
# 118      2    12.00       3.43  ...  0.93         3.05      564
# 80       2    12.72       1.81  ...  1.16         3.14      714
# 169      3    12.20       3.03  ...  0.66         1.83      510
# 167      3    13.58       2.58  ...  0.74         1.80      750
# 119      2    11.45       2.40  ...  0.80         3.39      625
# 87       2    11.64       2.06  ...  1.00         2.75      680
# 168      3    13.40       4.60  ...  0.67         1.92      630
# 129      3    12.86       1.35  ...  0.76         1.29      630
# 98       2    12.29       3.17  ...  1.42         2.83      406
# 135      3    12.25       4.72  ...  0.75         1.27      720
#
# [10 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   class                177 non-null    int64
#  1   alcohol              177 non-null    float64
#  2   malicAcid            177 non-null    float64
#  3   ash                  177 non-null    float64
#  4   ashalcalinity        177 non-null    float64
#  5   magnesium            177 non-null    int64
#  6   totalPhenols         177 non-null    float64
#  7   flavanoids           177 non-null    float64
#  8   nonFlavanoidPhenols  177 non-null    float64
#  9   proanthocyanins      177 non-null    float64
#  10  colorIntensity       177 non-null    float64
#  11  hue                  177 non-null    float64
#  12  od280_od315          177 non-null    float64
#  13  proline              177 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.5 KB

# %%
df.describe()
# Out:
#             class     alcohol   malicAcid  ...         hue  od280_od315      proline
# count  177.000000  177.000000  177.000000  ...  177.000000   177.000000   177.000000
# mean     1.943503   12.993672    2.339887  ...    0.956983     2.604294   745.096045
# std      0.773991    0.808808    1.119314  ...    0.229135     0.705103   314.884046
# min      1.000000   11.030000    0.740000  ...    0.480000     1.270000   278.000000
# 25%      1.000000   12.360000    1.600000  ...    0.780000     1.930000   500.000000
# 50%      2.000000   13.050000    1.870000  ...    0.960000     2.780000   672.000000
# 75%      3.000000   13.670000    3.100000  ...    1.120000     3.170000   985.000000
# max      3.000000   14.830000    5.800000  ...    1.710000     4.000000  1680.000000
#
# [8 rows x 14 columns]

# %%
sns.pairplot(df)

# %%
sns.distplot(df['class'], kde=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['alcohol'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['malicAcid'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['ash'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['ashalcalinity'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['magnesium'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['totalPhenols'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['flavanoids'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['nonFlavanoidPhenols'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['proanthocyanins'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['colorIntensity'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['hue'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['od280_od315'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['proline'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
fig = plt.figure(figsize=(30,17))
sns.heatmap(df.corr(), annot=True)

# %%
fig = plt.figure(figsize=(12,8))
sns.scatterplot(x='totalPhenols', y='flavanoids', data=df)

# %%
fig = plt.figure(figsize=(12,8))
sns.scatterplot(x='class', y='flavanoids', data=df)

# %%
fig = plt.figure(figsize=(7,5))
plt.hist(df['class'])
# Out:
# (array([58.,  0.,  0.,  0.,  0., 71.,  0.,  0.,  0., 48.]),
#  array([1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4, 2.6, 2.8, 3. ]),
#  <a list of 10 Patch objects>)

# %%
fig = plt.figure(figsize=(12,8))
sns.boxplot(x='class', y='flavanoids', data=df)

# %%
fig = plt.figure(figsize=(12,8))
sns.boxplot(x='class', y='totalPhenols', data=df)

# %%
fig = plt.figure(figsize=(12,8))
sns.boxplot(x='class', y='od280_od315', data=df)

# %%
fig = plt.figure(figsize=(12,8))
sns.scatterplot(x='od280_od315', y='flavanoids', data=df)

# %%
fig = plt.figure(figsize=(12,8))
sns.scatterplot(x='od280_od315', y='totalPhenols', data=df)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
min_max_scaler = MinMaxScaler()

# %%
df_minmax = min_max_scaler.fit_transform(df.drop(['class'], axis=1))

# %%
new_df = pd.DataFrame(df_minmax, columns=df.columns[1:14])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(new_df, df['class'], test_size=0.2, random_state=70)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                      weights='uniform')

# %%
predicted = knn.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score

# %%
confusion_matrix(y_test, predicted)
# Out:
# array([[15,  0,  0],
#        [ 2,  9,  0],
#        [ 0,  0, 10]])

# %%
print('Accuracy = ', accuracy_score(y_test, predicted))
print('F1 Score = ', f1_score(y_test, predicted, average='micro'))
print('Precision = ', precision_score(y_test, predicted, average= 'micro'))
print('Recall = ', recall_score(y_test, predicted, average= 'micro'))
# Out:
# Accuracy =  0.9444444444444444
# F1 Score =  0.9444444444444444
# Precision =  0.9444444444444444
# Recall =  0.9444444444444444

# %%
accuracy_lst = []

# %%
for i in range(1,70):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    predicted_i = knn.predict(X_test)
    accuracy_lst.append(accuracy_score(y_test, predicted_i))

# %%
plt.figure(figsize=(10,8))
plt.plot(range(1,70),accuracy_lst, color='black', linestyle='dashed', marker='o', markerfacecolor='blue', markersize=7)
plt.xlabel('K')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
X18_train, X18_test, y18_train, y18_test = train_test_split(new_df[['totalPhenols', 'flavanoids', 'hue', 'od280_od315', 'proline']], df['class'], test_size=0.2, random_state=70)

# %%
knn18 = KNeighborsClassifier(n_neighbors=1)

# %%
knn18.fit(X18_train, y18_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                      weights='uniform')

# %%
predicted18 = knn18.predict(X18_test)

# %%
confusion_matrix(y18_test, predicted18)
# Out:
# array([[14,  1,  0],
#        [ 4,  6,  1],
#        [ 0,  0, 10]])

# %%
print('Accuracy = ', accuracy_score(y18_test, predicted18))
print('F1 Score = ', f1_score(y18_test, predicted18, average='micro'))
print('Precision = ', precision_score(y18_test, predicted18, average= 'micro'))
print('Recall = ', recall_score(y18_test, predicted18, average= 'micro'))
# Out:
# Accuracy =  0.8333333333333334
# F1 Score =  0.8333333333333334
# Precision =  0.8333333333333334
# Recall =  0.8333333333333334

# %%
accuracy18_lst = []

# %%
for i in range(1,70):
    knn18 = KNeighborsClassifier(n_neighbors=i)
    knn18.fit(X18_train, y18_train)
    predicted18_i = knn18.predict(X18_test)
    accuracy18_lst.append(accuracy_score(y18_test, predicted18_i))

# %%
plt.figure(figsize=(10,8))
plt.plot(range(1,70),accuracy18_lst, color='black', linestyle='dashed', marker='o', markerfacecolor='blue', markersize=7)
plt.xlabel('K')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
X_std_train, X_std_test = train_test_split(df.drop(['class'], axis=1), test_size=0.2, random_state=70)

# %%
from sklearn.preprocessing import StandardScaler
sc_X_train = StandardScaler()

# %%
X_std_train = sc_X_train.fit_transform(X_std_train)
X_std_test = sc_X_train.fit_transform(X_std_test)

# %%
knn20 = KNeighborsClassifier(n_neighbors=1)

# %%
knn20.fit(X_std_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                      weights='uniform')

# %%
predicted20 = knn20.predict(X_std_test)

# %%
confusion_matrix(y_test, predicted20)
# Out:
# array([[15,  0,  0],
#        [ 1, 10,  0],
#        [ 0,  0, 10]])

# %%
print('Accuracy = ', accuracy_score(y18_test, predicted20))
print('F1 Score = ', f1_score(y18_test, predicted20, average='micro'))
print('Precision = ', precision_score(y18_test, predicted20, average= 'micro'))
print('Recall = ', recall_score(y18_test, predicted20, average= 'micro'))
# Out:
# Accuracy =  0.9722222222222222
# F1 Score =  0.9722222222222222
# Precision =  0.9722222222222222
# Recall =  0.9722222222222222

# %%
accuracy20_lst = []
for i in range(1,70):
    knn20 = KNeighborsClassifier(n_neighbors=i)
    knn20.fit(X_std_train, y_train)
    predicted20_i = knn20.predict(X_std_test)
    accuracy20_lst.append(accuracy_score(y_test, predicted20_i))

# %%
plt.figure(figsize=(10,8))
plt.plot(range(1,70),accuracy20_lst, color='black', linestyle='dashed', marker='o', markerfacecolor='blue', markersize=7)
plt.xlabel('K')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')
