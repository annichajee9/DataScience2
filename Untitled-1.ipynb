# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# Annicha Jeerasawat
# Occupation: Student

# %% [markdown]
# I am interested in data science because I love mathematics and I have a passion working as predicting the trends on business in the future

# %% [markdown]
# This is the sample of if-else for greeting you!

# %%
i = 99
if i < 50:
  print("I am beautiful")
elif i < 70:
  print("Nice to meet you")
elif i >= 100:
  print("Have a nice day!")
else:
  print("Glad to meet you here! Thank you for reviewing my assignment")
# Out:
# Glad to meet you here! Thank you for reviewing my assignment

# %%
import requests
from bs4 import BeautifulSoup
html_source = requests.get('https://www.ibm.com/products/content-manager')

# %%
html_source
# Out:
# <Response [200]>

# %%
raw_data = BeautifulSoup(html_source.content)
raw_data
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-us">
# <head>
# <meta charset="utf-8"/>
# <script>digitalData = {
#     "page": {
#         "category": [],
#         "pageInfo": {
#             "language": "en-US",
#             "country": "US",
#             "publisher": "IBM Corporation",
#             "version": "v19",
#             "ibm": {
#                 "contentDelivery": "Drupal 9",
#                 "contentProducer": "2583059 - Product Page",
#                 "owner": "Jide Iruka/US/IBM",
#                 "siteID": "DRUPAL",
#                 "contactModuleConfiguration": {
#                     "contactInformationBundleKey": {
#                         "focusArea": "Hybrid Cloud - Digital Bus Auto",
#                         "languageCode": "en",
#                         "regionCode": "US"
#                     },
#                     "contactModuleTranslationKey": {
#                         "languageCode": "en",
#                         "regionCode": "US"
# ...

# %%
from IPython.display import Image
Image(url= "https://www.thecoderpedia.com/wp-content/uploads/2020/06/Programming-Memes.jpg", width=400, height=400)
# Out:
# <img src="https://www.thecoderpedia.com/wp-content/uploads/2020/06/Programming-Memes.jpg" width="400" height="400"/>
